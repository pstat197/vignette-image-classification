# %%
! pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-2.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (91 kB)
# Collecting numpy>=1.23.2 (from pandas)
#   Using cached numpy-2.3.5-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/madhav/vignette-image-classification/.venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /Users/madhav/vignette-image-classification/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.3.3-cp311-cp311-macosx_11_0_arm64.whl (10.8 MB)
# Using cached numpy-2.3.5-cp311-cp311-macosx_14_0_arm64.whl (5.4 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [pandas]

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
img_file_path = '../data_sample'

filenames = os.listdir(img_file_path)
labels = [x.split(".")[0] for x in filenames]

data_names_df = pd.DataFrame({"filename": filenames, "label": labels})

data_names_df.head(10)
# Out:
#         filename label
# 0      cat.6.jpg   cat
# 1      cat.7.jpg   cat
# 2      cat.4.jpg   cat
# 3      cat.0.jpg   cat
# 4      cat.1.jpg   cat
# 5      cat.3.jpg   cat
# 6      cat.2.jpg   cat
# 7  dog.11573.jpg   dog
# 8  dog.11577.jpg   dog
# 9  dog.11576.jpg   dog

# %%
img = Image.open(os.path.join(img_file_path, filenames[0]))
img_array = np.array(img)
print(img_array.shape)

# %%
for filename in filenames:
    img = Image.open(os.path.join(img_file_path, filename))
    print(f"{filename}: {np.array(img).shape}")

# %%
img = Image.open(os.path.join(img_file_path, filenames[0]))
img_array = np.array(img)
print(img_array.shape)
# Out:
# (303, 400, 3)

# %%
def prepare_ml_data(data_path, target_size=(64, 64)):
    filenames = [f for f in os.listdir(data_path) if f.endswith('.jpg')]
    X, y = [], []
    for filename in filenames:
        img = Image.open(os.path.join(data_path, filename)).convert('RGB').resize(target_size)
        img_array = np.array(img).astype(np.float32) / 255.0
        X.append(img_array.flatten())
        y.append(0 if filename.split('.')[0] == 'cat' else 1)
    return np.array(X), np.array(y)

# %%
def prepare_dl_data(data_path, target_size=(224, 224)):
    filenames = [f for f in os.listdir(data_path) if f.endswith('.jpg')]
    X, y = [], []
    for filename in filenames:
        img = Image.open(os.path.join(data_path, filename)).convert('RGB').resize(target_size)
        img_array = np.array(img).astype(np.float32) / 255.0
        X.append(img_array)
        y.append(0 if filename.split('.')[0] == 'cat' else 1)
    return np.array(X), np.array(y)
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.839216  0.733333  0.780392  0.819608  0.717647  0.760784  0.823529
# 1   0.121569  0.050980  0.003922  0.145098  0.058824  0.003922  0.188235
# 2   0.588235  0.545098  0.517647  0.647059  0.607843  0.580392  0.678431
# 3   0.807843  0.654902  0.352941  0.835294  0.682353  0.380392  0.866667
# 4   0.149020  0.168627  0.160784  0.172549  0.184314  0.207843  0.172549
# 5   0.650980  0.611765  0.556863  0.690196  0.623529  0.576471  0.756863
# 6   0.321569  0.258824  0.309804  0.290196  0.231373  0.282353  0.329412
# 7   0.466667  0.486275  0.607843  0.600000  0.545098  0.654902  0.776471
# 8   0.647059  0.631373  0.694118  0.615686  0.584314  0.611765  0.549020
# 9   0.525490  0.521569  0.552941  0.643137  0.639216  0.674510  0.690196
# 10  0.078431  0.078431  0.098039  0.058824  0.086275  0.117647  0.113725
# 11  0.345098  0.298039  0.235294  0.400000  0.341176  0.274510  0.474510
# 12  0.254902  0.223529  0.219608  0.211765  0.200000  0.207843  0.321569
# 13  0.227451  0.223529  0.223529  0.380392  0.360784  0.317647  0.388235
# 14  0.921569  0.968627  0.866667  0.968627  0.972549  0.925490  0.976471
# 15  0.992157  0.984314  0.988235  0.992157  0.988235  0.992157  0.984314
# 16  0.505882  0.450980  0.415686  0.564706  0.509804  0.474510  0.592157
# 17  0.129412  0.152941  0.184314  0.156863  0.176471  0.227451  0.168627
